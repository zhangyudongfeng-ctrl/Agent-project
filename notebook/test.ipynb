# %%
import os
os.chdir("D:/Agent-project")  # 切到项目根目录

# %load_ext autoreload   
# %autoreload 2           
# 启用 autoreload 扩展
# 模式 2:每次执行 cell 前自动重载所有 import 的模块

import sys
sys.path.append("D:/Agent-project")
from pathlib import Path
BASE_DIR = Path.cwd()
print(BASE_DIR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10 sys.path.append("D:/Agent-project")
#      11 from pathlib import Path
# ---> 12 BASE_DIR = Path(__file__).resolve().parent.parent
#      13 print(BASE_DIR)
#
# NameError: name '__file__' is not defined
